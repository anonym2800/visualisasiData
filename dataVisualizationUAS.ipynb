# %% [markdown]
# <a href="https://colab.research.google.com/github/anonym2800/visualizationData/blob/main/dataVisualizationUAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Mengambil data dari resource
data = pd.read_csv('sample_data/kebutuhan_per_bulan_2.csv')
data

# %%
# Filtering propinsi
data_filtered = data [data['Propinsi']=='MALUKU']
data_filtered
# Out:
#     Propinsi  tahun kebutuhan
# 30    MALUKU   2005    602938
# 64    MALUKU   2006   1076699
# 98    MALUKU   2007   1091195
# 132   MALUKU   2008   1182556
# 166   MALUKU   2009   1280599
# 200   MALUKU   2010   1400990
# 234   MALUKU   2011   1570980
# 268   MALUKU   2012   1739000
# 302   MALUKU   2013   1738676
# 336   MALUKU   2014   2158469
# 370   MALUKU   2015   2197450

# %%
# TABEL PERTAMA
x = data_filtered['tahun']
y = data_filtered['kebutuhan']

plt.scatter(x, y)

#add label
plt.xlabel("Tahun", fontsize = 13)
plt.ylabel("Kebutuhan" , fontsize = 13)
plt.title('Kebutuhan per bulan pada Maluku', fontweight ="bold",)
plt.show()

# %%
# Filtering Propinsi
data_filtered_jabar = data [data['Propinsi']=='JAWA BARAT']
data_filtered_jabar
# Out:
#        Propinsi  tahun kebutuhan
# 11   JAWA BARAT   2005    408259
# 45   JAWA BARAT   2006    542621
# 79   JAWA BARAT   2007    607425
# 113  JAWA BARAT   2008    614275
# 147  JAWA BARAT   2009    731680
# 181  JAWA BARAT   2010    743141
# 215  JAWA BARAT   2011    874693
# 249  JAWA BARAT   2012    874693
# 283  JAWA BARAT   2013    946689
# 317  JAWA BARAT   2014    946689
# 351  JAWA BARAT   2015    946689

# %%
# TABEL KEDUA
y = data_filtered_jabar["kebutuhan"]
x = data_filtered_jabar["tahun"]

#Bars
plt.bar(x, y)

#line
plt.plot(x, y, 'o-', color='red')

#add label
plt.xlabel("Tahun", fontsize = 13)
plt.ylabel("Kebutuhan" , fontsize = 13)
plt.title('Kebutuhan per bulan pada Jawa Barat', fontweight ="bold",)
plt.show()

# %%
# Mengambil data dari resource
df = pd.read_csv('sample_data/SupplyKantor.csv')
df
# Out:
#    TanggalPesan        Kota SalesRep    Jenis  Jumlah  Harga Satuan
# 0     30-Mar-17     Jakarta  Richard  Pen Set      62          4990
# 1     07-Apr-17    Surabaya     Nono   Binder      29          1990
# 2     16-Apr-17    Surabaya     Nono  Pen Set      55         12490
# 3     24-Apr-17     Bandung    Susan   Binder      81         19990
# 4     03-May-17    Surabaya    Mamat  Pen Set      42         23950
# 5     11-May-17     Jakarta  Richard   Pencil      35          4990
# 6     20-May-17  Yogyakarta   Jajang     Desk       3        275000
# 7     28-May-17     Bandung    Smith     Desk       2        125000
# 8     06-Jun-17     Bandung     Bobi   Pencil       7          1290
# 9     14-Jun-17     Jakarta  Richard  Pen Set      16         15990
# 10    23-Jun-17  Yogyakarta   Jajang      Pen      76          1990
# 11    01-Jul-17     Bandung   Morgan   Binder      28          8990
# 12    10-Jul-17     Bandung   Thomas   Binder      57         19990
# ...

# %%
# sort by
